# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataframe = pd.read_csv("data/VentasPorProveedor.csv",skiprows=5,sep=";",parse_dates=["Fecha"],date_format="%d/%m/%Y",decimal=",")

# %%
dataframe.head(15)
# Out:
#         Fecha          Vendedor Región           Artículo    Categoría
# 0  2016-01-01      Steve Ashton  Norte   Medias Femeninas   Vestimenta  \
# 1  2016-01-01  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  2016-01-01        Sarah Bond    Sur             Gorras   Vestimenta
# 3  2016-01-01   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  2016-01-01   Desmond Delaney   Este          Chocolate  Comestibles
# 5  2016-01-01  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6  2016-01-01    Boris Stanford  Norte          Pepinillo  Comestibles
# 7  2016-01-01      Steve Ashton  Oeste             Gorras   Vestimenta
# 8  2016-01-01  Trevor Snodgrass   Este                Pan  Comestibles
# 9  2016-01-01        Sarah Bond   Este          Caramelos  Comestibles
# 10 2016-01-01  Trevor Snodgrass    Sur                Pan  Comestibles
# 11 2016-01-01    Boris Stanford  Oeste         Calcetines   Vestimenta
# ...

# %%
dataframe.shape
# Out:
# (460, 7)

# %%
dataframe.tail(15)
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría
# 445 2016-01-31   Desmond Delaney    Sur         Escobillón        Hogar  \
# 446 2016-01-31  Trevor Snodgrass  Oeste           Sudadera   Vestimenta
# 447 2016-01-31   Desmond Delaney   Este           Bombilla        Hogar
# 448 2016-01-31      Steve Ashton  Oeste              Lejía        Hogar
# 449 2016-01-31    Boris Stanford   Este           Sudadera   Vestimenta
# 450 2016-01-31    Boris Stanford   Este          Chocolate  Comestibles
# 451 2016-01-31      Steve Ashton  Norte         Detergente        Hogar
# 452 2016-01-31        Dustin Gee  Oeste          Caramelos  Comestibles
# 453 2016-01-31        Sarah Bond  Norte           Bombilla        Hogar
# 454 2016-01-31        Dustin Gee  Oeste      Limpiavidrios        Hogar
# 455 2016-01-31        Sarah Bond    Sur            Bufanda   Vestimenta
# 456 2016-01-31        Dustin Gee   Este          Sandalias   Vestimenta
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      460 non-null    datetime64[ns]
#  1   Vendedor   460 non-null    object
#  2   Región     460 non-null    object
#  3   Artículo   460 non-null    object
#  4   Categoría  460 non-null    object
#  5   Unidades   460 non-null    int64
#  6   Ganancia   460 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 25.3+ KB

# %%
dataframe["Región"].value_counts(ascending=True,dropna=True)
# Out:
# Región
# Norte    100
# Oeste    102
# Sur      120
# Este     138
# Name: count, dtype: int64

# %%
dataframe.sort_values(by=["Vendedor", "Ganancia"], ascending=[True,False])
# Out:
#          Fecha          Vendedor Región       Artículo    Categoría  Unidades
# 43  2016-01-04    Boris Stanford   Este      Sandalias   Vestimenta         9  \
# 299 2016-01-20    Boris Stanford  Oeste      Sandalias   Vestimenta         9
# 373 2016-01-26    Boris Stanford    Sur       Sudadera   Vestimenta         9
# 291 2016-01-20    Boris Stanford  Oeste         Shorts   Vestimenta        11
# 370 2016-01-26    Boris Stanford    Sur         Shorts   Vestimenta        10
# ..         ...               ...    ...            ...          ...       ...
# 95  2016-01-06  Trevor Snodgrass  Norte  Limpiavidrios        Hogar         2
# 117 2016-01-08  Trevor Snodgrass  Oeste      Pepinillo  Comestibles         5
# 98  2016-01-06  Trevor Snodgrass   Este            Pan  Comestibles         2
# 312 2016-01-21  Trevor Snodgrass  Oeste      Pepinillo  Comestibles         2
# 248 2016-01-16  Trevor Snodgrass  Oeste        Cerveza  Comestibles         1
#
#      Ganancia
# 43       94.5
# ...

# %%
dataframe[(dataframe["Artículo"] == "Gorras") & (dataframe["Región"] == "Norte")]
# Out:
#          Fecha          Vendedor Región Artículo   Categoría  Unidades
# 85  2016-01-06        Sarah Bond  Norte   Gorras  Vestimenta         9  \
# 156 2016-01-10  Trevor Snodgrass  Norte   Gorras  Vestimenta         7
# 159 2016-01-11      Steve Ashton  Norte   Gorras  Vestimenta         2
# 201 2016-01-14   Desmond Delaney  Norte   Gorras  Vestimenta         5
# 360 2016-01-25      Steve Ashton  Norte   Gorras  Vestimenta         7
# 368 2016-01-26    Boris Stanford  Norte   Gorras  Vestimenta         7
# 394 2016-01-27      Steve Ashton  Norte   Gorras  Vestimenta        14
# 396 2016-01-27  Trevor Snodgrass  Norte   Gorras  Vestimenta         3
#
#      Ganancia
# 85       18.9
# 156      14.7
# 159       4.2
# 201      10.5
# 360      14.7
# 368      14.7
# 394      29.4
# 396       6.3

# %%
dataframe[dataframe.Vendedor.str.contains("Trevor")]
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades
# 1   2016-01-01  Trevor Snodgrass  Oeste   Chocolate  Comestibles         8  \
# 5   2016-01-01  Trevor Snodgrass   Este     Cerveza  Comestibles        15
# 8   2016-01-01  Trevor Snodgrass   Este         Pan  Comestibles        12
# 10  2016-01-01  Trevor Snodgrass    Sur         Pan  Comestibles         6
# 12  2016-01-01  Trevor Snodgrass    Sur      Shorts   Vestimenta         6
# ..         ...               ...    ...         ...          ...       ...
# 437 2016-01-30  Trevor Snodgrass   Este  Calcetines   Vestimenta        10
# 440 2016-01-30  Trevor Snodgrass   Este      Gorras   Vestimenta         6
# 442 2016-01-31  Trevor Snodgrass   Este   Sandalias   Vestimenta         6
# 446 2016-01-31  Trevor Snodgrass  Oeste    Sudadera   Vestimenta         2
# 459 2016-01-31  Trevor Snodgrass    Sur   Pepinillo  Comestibles         7
#
#      Ganancia
# 1        3.84
# 5        6.00
# 8        4.80
# ...

# %%
ali = dataframe["Categoría"] == "Comestibles"

# %%
dataframe[ali]
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría
# 1   2016-01-01  Trevor Snodgrass  Oeste          Chocolate  Comestibles  \
# 3   2016-01-01   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4   2016-01-01   Desmond Delaney   Este          Chocolate  Comestibles
# 5   2016-01-01  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6   2016-01-01    Boris Stanford  Norte          Pepinillo  Comestibles
# ..         ...               ...    ...                ...          ...
# 444 2016-01-31        Dustin Gee  Oeste  Sánguche de Queso  Comestibles
# 450 2016-01-31    Boris Stanford   Este          Chocolate  Comestibles
# 452 2016-01-31        Dustin Gee  Oeste          Caramelos  Comestibles
# 457 2016-01-31        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 459 2016-01-31  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades  Ganancia
# 1           8      3.84
# 3           9     14.40
# 4          14      6.72
# ...

# %%
dataframe.Artículo[ali].value_counts().plot();

# %%
dataframe.Artículo[ali].value_counts().plot(kind="bar",color="pink",figsize=(10,10));

# %%
dataframe.Artículo[ali].value_counts().plot(kind="barh");

# %%
dataframe.Artículo[ali].value_counts().plot(kind="pie",colormap="ocean");

# %%
dataframe.plot(kind="scatter",x="Unidades",y="Ganancia");

# %%
type(dataframe.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
dataframe.index[22]
# Out:
# 22

# %%
dataframe.set_index("Vendedor",inplace=True)

# %%
dataframe.head()
# Out:
#                       Fecha Región           Artículo    Categoría  Unidades
# Vendedor
# Steve Ashton     2016-01-01  Norte   Medias Femeninas   Vestimenta         6  \
# Trevor Snodgrass 2016-01-01  Oeste          Chocolate  Comestibles         8
# Sarah Bond       2016-01-01    Sur             Gorras   Vestimenta         3
# Desmond Delaney  2016-01-01    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney  2016-01-01   Este          Chocolate  Comestibles        14
#
#                   Ganancia
# Vendedor
# Steve Ashton         18.00
# Trevor Snodgrass      3.84
# Sarah Bond            6.30
# Desmond Delaney      14.40
# Desmond Delaney       6.72

# %%
dataframe.reset_index(inplace=True)

# %%
dataframe.head()
# Out:
#            Vendedor      Fecha Región           Artículo    Categoría
# 0      Steve Ashton 2016-01-01  Norte   Medias Femeninas   Vestimenta  \
# 1  Trevor Snodgrass 2016-01-01  Oeste          Chocolate  Comestibles
# 2        Sarah Bond 2016-01-01    Sur             Gorras   Vestimenta
# 3   Desmond Delaney 2016-01-01    Sur  Sánguche de Queso  Comestibles
# 4   Desmond Delaney 2016-01-01   Este          Chocolate  Comestibles
#
#    Unidades  Ganancia
# 0         6     18.00
# 1         8      3.84
# 2         3      6.30
# 3         9     14.40
# 4        14      6.72

# %%
dataframe.set_index("Vendedor",inplace=True)

# %%
dataframe.sort_index(inplace=True)

# %%
dataframe.head(15)
# Out:
#                     Fecha Región    Artículo    Categoría  Unidades  Ganancia
# Vendedor
# Boris Stanford 2016-01-13    Sur      Escoba        Hogar         1      3.65
# Boris Stanford 2016-01-05    Sur      Shorts   Vestimenta         1      4.90
# Boris Stanford 2016-01-05   Este  Escobillón        Hogar         8      6.80
# Boris Stanford 2016-01-18    Sur   Pepinillo  Comestibles         5      1.50
# Boris Stanford 2016-01-05    Sur         Pan  Comestibles         4      1.60
# Boris Stanford 2016-01-18    Sur  Escobillón        Hogar         9      7.65
# Boris Stanford 2016-01-28   Este     Bufanda   Vestimenta         9     24.75
# Boris Stanford 2016-01-19    Sur  Escobillón        Hogar        14     11.90
# Boris Stanford 2016-01-19  Oeste       Lejía        Hogar        12     37.20
# Boris Stanford 2016-01-04  Norte  Calcetines   Vestimenta         6     13.50
# Boris Stanford 2016-01-04    Sur   Sandalias   Vestimenta         4     42.00
# ...

# %%
dataframe.loc["Boris Stanford"]
# Out:
#                     Fecha Región    Artículo    Categoría  Unidades  Ganancia
# Vendedor
# Boris Stanford 2016-01-13    Sur      Escoba        Hogar         1      3.65
# Boris Stanford 2016-01-05    Sur      Shorts   Vestimenta         1      4.90
# Boris Stanford 2016-01-05   Este  Escobillón        Hogar         8      6.80
# Boris Stanford 2016-01-18    Sur   Pepinillo  Comestibles         5      1.50
# Boris Stanford 2016-01-05    Sur         Pan  Comestibles         4      1.60
# ...                   ...    ...         ...          ...       ...       ...
# Boris Stanford 2016-01-22    Sur    Sudadera   Vestimenta         5     30.00
# Boris Stanford 2016-01-03   Este      Shorts   Vestimenta         7     34.30
# Boris Stanford 2016-01-31   Este   Chocolate  Comestibles         3      1.44
# Boris Stanford 2016-01-22   Este     Cerveza  Comestibles         8      3.20
# Boris Stanford 2016-01-23  Oeste     Cerveza  Comestibles        15      6.00
#
# [69 rows x 6 columns]

# %%
dataframe.loc["Sarah Bond"]
# Out:
#                 Fecha Región           Artículo    Categoría  Unidades
# Vendedor
# Sarah Bond 2016-01-28   Este  Sánguche de Queso  Comestibles         7  \
# Sarah Bond 2016-01-05  Norte                Pan  Comestibles         3
# Sarah Bond 2016-01-22  Oeste          Sandalias   Vestimenta         2
# Sarah Bond 2016-01-27    Sur           Bombilla        Hogar        12
# Sarah Bond 2016-01-04   Este            Bufanda   Vestimenta        14
# ...               ...    ...                ...          ...       ...
# Sarah Bond 2016-01-09  Norte           Bombilla        Hogar         6
# Sarah Bond 2016-01-09    Sur               Soda  Comestibles        11
# Sarah Bond 2016-01-09  Oeste          Pepinillo  Comestibles         2
# Sarah Bond 2016-01-15    Sur          Chocolate  Comestibles         4
# Sarah Bond 2016-01-15   Este         Detergente        Hogar         2
#
#             Ganancia
# Vendedor
# Sarah Bond     11.20
# Sarah Bond      1.20
# Sarah Bond     21.00
# ...

# %%
dataframe.reset_index(inplace=True)
dataframe.head()
# Out:
#          Vendedor      Fecha Región    Artículo    Categoría  Unidades
# 0  Boris Stanford 2016-01-13    Sur      Escoba        Hogar         1  \
# 1  Boris Stanford 2016-01-05    Sur      Shorts   Vestimenta         1
# 2  Boris Stanford 2016-01-05   Este  Escobillón        Hogar         8
# 3  Boris Stanford 2016-01-18    Sur   Pepinillo  Comestibles         5
# 4  Boris Stanford 2016-01-05    Sur         Pan  Comestibles         4
#
#    Ganancia
# 0      3.65
# 1      4.90
# 2      6.80
# 3      1.50
# 4      1.60

# %%
dataframe.loc[dataframe.Vendedor == "Sarah Bond"]
# Out:
#        Vendedor      Fecha Región           Artículo    Categoría  Unidades
# 215  Sarah Bond 2016-01-28   Este  Sánguche de Queso  Comestibles         7  \
# 216  Sarah Bond 2016-01-05  Norte                Pan  Comestibles         3
# 217  Sarah Bond 2016-01-22  Oeste          Sandalias   Vestimenta         2
# 218  Sarah Bond 2016-01-27    Sur           Bombilla        Hogar        12
# 219  Sarah Bond 2016-01-04   Este            Bufanda   Vestimenta        14
# ..          ...        ...    ...                ...          ...       ...
# 296  Sarah Bond 2016-01-09  Norte           Bombilla        Hogar         6
# 297  Sarah Bond 2016-01-09    Sur               Soda  Comestibles        11
# 298  Sarah Bond 2016-01-09  Oeste          Pepinillo  Comestibles         2
# 299  Sarah Bond 2016-01-15    Sur          Chocolate  Comestibles         4
# 300  Sarah Bond 2016-01-15   Este         Detergente        Hogar         2
#
#      Ganancia
# 215     11.20
# 216      1.20
# ...

# %%
dataframe.iloc[233]
# Out:
# Vendedor              Sarah Bond
# Fecha        2016-01-02 00:00:00
# Región                     Norte
# Artículo                 Bufanda
# Categoría             Vestimenta
# Unidades                       4
# Ganancia                    11.0
# Name: 233, dtype: object

# %%
dataframe.iloc[[233,23,54,88]]
# Out:
#             Vendedor      Fecha Región           Artículo    Categoría
# 233       Sarah Bond 2016-01-02  Norte            Bufanda   Vestimenta  \
# 23    Boris Stanford 2016-01-09    Sur  Sánguche de Queso  Comestibles
# 54    Boris Stanford 2016-01-27   Este                Pan  Comestibles
# 88   Desmond Delaney 2016-01-08   Este         Detergente        Hogar
#
#      Unidades  Ganancia
# 233         4      11.0
# 23         10      16.0
# 54          8       3.2
# 88         15      37.2

# %%
dataframe.iloc[1:233]
# Out:
#            Vendedor      Fecha Región    Artículo    Categoría  Unidades
# 1    Boris Stanford 2016-01-05    Sur      Shorts   Vestimenta         1  \
# 2    Boris Stanford 2016-01-05   Este  Escobillón        Hogar         8
# 3    Boris Stanford 2016-01-18    Sur   Pepinillo  Comestibles         5
# 4    Boris Stanford 2016-01-05    Sur         Pan  Comestibles         4
# 5    Boris Stanford 2016-01-18    Sur  Escobillón        Hogar         9
# ..              ...        ...    ...         ...          ...       ...
# 228      Sarah Bond 2016-01-18    Sur         Pan  Comestibles        12
# 229      Sarah Bond 2016-01-18    Sur  Escobillón        Hogar         6
# 230      Sarah Bond 2016-01-01    Sur      Gorras   Vestimenta         3
# 231      Sarah Bond 2016-01-31    Sur     Bufanda   Vestimenta         6
# 232      Sarah Bond 2016-01-01   Este   Caramelos  Comestibles        15
#
#      Ganancia
# 1        4.90
# 2        6.80
# 3        1.50
# 4        1.60
# ...

# %%
dataframe.groupby("Región")

# %%
for gk, gv in dataframe.groupby("Región"):
    print(gk)
    print(gv)
# Out:
# Este
#              Vendedor      Fecha Región           Artículo    Categoría
# 2      Boris Stanford 2016-01-05   Este         Escobillón        Hogar  \
# 6      Boris Stanford 2016-01-28   Este            Bufanda   Vestimenta
# 11     Boris Stanford 2016-01-04   Este             Shorts   Vestimenta
# 15     Boris Stanford 2016-01-31   Este           Sudadera   Vestimenta
# 17     Boris Stanford 2016-01-04   Este          Sandalias   Vestimenta
# ..                ...        ...    ...                ...          ...
# 449  Trevor Snodgrass 2016-01-16   Este         Detergente        Hogar
# 452  Trevor Snodgrass 2016-01-15   Este             Gorras   Vestimenta
# 453  Trevor Snodgrass 2016-01-15   Este           Sudadera   Vestimenta
# 454  Trevor Snodgrass 2016-01-15   Este         Detergente        Hogar
# 456  Trevor Snodgrass 2016-01-14   Este  Sánguche de Queso  Comestibles
#
#      Unidades  Ganancia
# 2           8      6.80
# 6           9     24.75
# ...

# %%
dataframe.groupby("Región").size()
# Out:
# Región
# Este     138
# Norte    100
# Oeste    102
# Sur      120
# dtype: int64

# %%
dataframe.groupby(["Región","Vendedor","Ganancia"]).agg(["min","max","count"])
# Out:
#                                       Fecha
#                                         min        max count
# Región Vendedor         Ganancia
# Este   Boris Stanford   1.44     2016-01-31 2016-01-31     1  \
#                         1.60     2016-01-02 2016-01-02     1
#                         3.20     2016-01-22 2016-01-27     2
#                         3.60     2016-01-15 2016-01-15     1
#                         5.40     2016-01-14 2016-01-14     1
# ...                                     ...        ...   ...
# Sur    Trevor Snodgrass 27.00    2016-01-24 2016-01-24     1
#                         29.20    2016-01-27 2016-01-27     1
#                         29.40    2016-01-01 2016-01-01     1
#                         33.00    2016-01-27 2016-01-27     1
#                         40.15    2016-01-02 2016-01-02     1
#
#                                           Artículo
#                                                min               max count
# ...

# %%
dataframe.groupby(["Región","Vendedor","Ganancia"]).agg({"Región":["min","max","count"]})
# Out:
#                                  Región
#                                     min   max count
# Región Vendedor         Ganancia
# Este   Boris Stanford   1.44       Este  Este     1
#                         1.60       Este  Este     1
#                         3.20       Este  Este     2
#                         3.60       Este  Este     1
#                         5.40       Este  Este     1
# ...                                 ...   ...   ...
# Sur    Trevor Snodgrass 27.00       Sur   Sur     1
#                         29.20       Sur   Sur     1
#                         29.40       Sur   Sur     1
#                         33.00       Sur   Sur     1
#                         40.15       Sur   Sur     1
#
# [427 rows x 3 columns]

# %%
dataframe.loc[dataframe.Vendedor == "Sarah Bond"].groupby(["Vendedor","Región"]).agg({"Ganancia":["sum","min","max"]})
# Out:
#                   Ganancia
#                        sum   min    max
# Vendedor   Región
# Sarah Bond Este     427.42  1.80   44.1
#            Norte    321.01  0.85   58.8
#            Oeste     91.93  0.60   21.0
#            Sur      315.68  0.60  157.5

# %%
dataframe_sarah = dataframe[(dataframe.Vendedor == "Sarah Bond") & ((dataframe["Categoría"] == "Comestibles")|(dataframe["Categoría"] == "Hogar"))]

# %%
dataframe_sarah_size = dataframe_sarah.groupby(["Artículo","Categoría","Región"]).size()

# %%
dataframe_sarah_size_unstack = dataframe_sarah_size.unstack("Región")

# %%
dataframe_sarah_size_unstack.stack()
# Out:
# Artículo           Categoría    Región
# Bombilla           Hogar        Norte     2.0
#                                 Sur       2.0
# Caramelos          Comestibles  Este      1.0
#                                 Norte     2.0
# Cerveza            Comestibles  Este      2.0
#                                 Norte     2.0
#                                 Sur       1.0
# Chocolate          Comestibles  Este      1.0
#                                 Norte     2.0
#                                 Oeste     1.0
#                                 Sur       2.0
# Detergente         Hogar        Este      2.0
#                                 Norte     2.0
#                                 Oeste     2.0
#                                 Sur       1.0
# Escoba             Hogar        Este      2.0
#                                 Norte     1.0
#                                 Sur       1.0
# Escobillón         Hogar        Este      1.0
# ...

# %%
dataframe_sarah_size_unstack.unstack(fill_value="0")
# Out:
# Región                   Este             Norte             Oeste
# Categoría         Comestibles Hogar Comestibles Hogar Comestibles Hogar
# Artículo
# Bombilla                    0   NaN           0   2.0           0   NaN  \
# Caramelos                 1.0     0         2.0     0         NaN     0
# Cerveza                   2.0     0         2.0     0         NaN     0
# Chocolate                 1.0     0         2.0     0         1.0     0
# Detergente                  0   2.0           0   2.0           0   2.0
# Escoba                      0   2.0           0   1.0           0   NaN
# Escobillón                  0   1.0           0   2.0           0   NaN
# Lejía                       0   NaN           0   1.0           0   NaN
# Limpiavidrios               0   4.0           0   NaN           0   NaN
# Pan                       NaN     0         2.0     0         NaN     0
# Pepinillo                 1.0     0         1.0     0         1.0     0
# ...
